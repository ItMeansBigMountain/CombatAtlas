# %% [markdown]
# # Print 1 --> 1000

# %% [markdown]
# # Print Odds 1 --> 1000

# %% [markdown]
# # Print Total
#
# 1 + 2 + 3 + 4

# %% [markdown]
# # Array Values
#
# "use for loop to show each value inside of the array"

# %% [markdown]
# # Print Max in array
# [1 , 3 , 3 , 7]   or!   [7 , 3 , 3 , 1]
#
# 7

# %% [markdown]
# # Print Average in array
# [ 1, 3 , 3 , 7]
#
# ?

# %% [markdown]
# # Create array of 1 --> 1000  [ODD NUMBERS ONLY]

# %%
arr = []

# INSERT CODING MAGIC HERE

print( arr )

# %% [markdown]
# # Square each value in array
# [ 1 , 3 , 3 , 7 ] ==> [ 1 , 9 , 9 , 49 ]

# %% [markdown]
# # Return array count greater than VAR

# %%
var = None
count = 0



# INSERT CODING SORCERY HERE




print( count )

# %% [markdown]
# # Change all negative values to zero
# [ 1 , -3 , -3 , 7 ]

# %% [markdown]
# # MAX MIN AVG
# print all three!

# %% [markdown]
# # Shift array values to the left
# Leave the last value zero
#
# [ 1 , 3 , 3 , 7 ] ==> [ 3 , 3 , 7 , 0 ]

# %% [markdown]
# # Negative value turns into a string
# similar to before...

# %% [markdown]
# # RANDOM NUMBER GENERATOR --> update all previous algorithms
#
# replace the arr variable with the random number array from the snippet below

# %%
import random

random_number_array = []
for i in range( 0 , 10 , 1 ):
    secret_number = random.randint( 0 , 100 )
    random_number_array.append(  secret_number  )


random_number_array

# %% [markdown]
# # Congratulations!
#
# You made it this far! Hopefully at this point, you know how to use for loops to execute calculations on data types such as arrays...  you may also hear the phrase "Data Model" when talking about arrays or tuples
